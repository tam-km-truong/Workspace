# %%
import pandas as pd
import numpy as np
import random

# %%
bakrep_metadata = pd.read_csv("/Users/ktruong/workspace/Workspace/jupyter_notebook/data/bakrep-export_18112024.tsv",sep='\t', low_memory=False, index_col="#id")

# %%
[tup for tup in zip(bakrep_metadata.columns, bakrep_metadata.dtypes)]
# Out:
# [('bakta.genome.genus', dtype('O')),
#  ('bakta.genome.species', dtype('O')),
#  ('bakta.genome.strain', dtype('O')),
#  ('bakta.stats.no_sequences', dtype('float64')),
#  ('bakta.stats.size', dtype('float64')),
#  ('bakta.stats.gc', dtype('float64')),
#  ('bakta.stats.n_ratio', dtype('float64')),
#  ('bakta.stats.n50', dtype('float64')),
#  ('bakta.stats.coding_ratio', dtype('float64')),
#  ('gtdbtk.classification.domain', dtype('O')),
#  ('gtdbtk.classification.phylum', dtype('O')),
#  ('gtdbtk.classification.class', dtype('O')),
#  ('gtdbtk.classification.order', dtype('O')),
#  ('gtdbtk.classification.family', dtype('O')),
#  ('gtdbtk.classification.genus', dtype('O')),
#  ('gtdbtk.classification.species', dtype('O')),
#  ('mlst.sequence_type', dtype('O')),
#  ('checkm2.quality.completeness', dtype('float64')),
#  ('checkm2.quality.contamination', dtype('float64')),
#  ('metadata.accession', dtype('O')),
#  ('metadata.collected_by', dtype('O')),
# ...

# %%
species_groups =  bakrep_metadata.groupby(['gtdbtk.classification.species']).groups
group_sizes = bakrep_metadata.groupby(['gtdbtk.classification.species']).size()

# %%
group_sizes.sort_values()
# Out:
# gtdbtk.classification.species
# 1-14-0-20-39-49 sp002787635         1
# Pantoea brenneri                    1
# Pantoea anthophila                  1
# Pantoea allii                       1
# Pannonibacter phragmitetus          1
#                                 ...
# Staphylococcus aureus           47997
# Mycobacterium tuberculosis      49020
# Streptococcus pneumoniae        51433
# Escherichia coli                89136
# Salmonella enterica            178585
# Length: 8207, dtype: int64

# %%
ecoli = bakrep_metadata[bakrep_metadata['gtdbtk.classification.species']=='Escherichia coli']
ecoli
# Out:
#              bakta.genome.genus bakta.genome.species bakta.genome.strain  \
# #id
# SAMD00000649           Shigella          dysenteriae             unknown
# SAMD00000699        Escherichia                 coli             unknown
# SAMD00000724        Escherichia                 coli             unknown
# SAMD00000754        Escherichia                 coli             unknown
# SAMD00000812           Shigella          dysenteriae             unknown
# ...                         ...                  ...                 ...
# SAMN10397942        Escherichia                 coli             unknown
# SAMN10397943        Escherichia                 coli             unknown
# SAMN10397944           Shigella             flexneri             unknown
# SAMN10402087           Shigella               sonnei             unknown
# SAMN10402105           Shigella               sonnei             unknown
#
#               bakta.stats.no_sequences  bakta.stats.size  bakta.stats.gc  \
# #id
# ...

# %%
seeds = (9062025,10062025,11062025,12062025,13062025)
selection_01 = ecoli.sample(frac=0.01, random_state=seeds[0])
selection_01
# Out:
#              bakta.genome.genus bakta.genome.species bakta.genome.strain  \
# #id
# SAMEA3108803        Escherichia                 coli            NHES0026
# SAMN04102158        Escherichia                 coli        PNUSAE001415
# SAMN06019236        Escherichia                 coli              282681
# SAMN05440375        Escherichia                 coli         MOD1-EC5564
# SAMEA2054469           Shigella               sonnei     2090STDY5461811
# ...                         ...                  ...                 ...
# SAMN08501100        Escherichia                 coli        PNUSAE011602
# SAMN04323339        Escherichia                 coli        PNUSAE001793
# SAMEA2517801           Shigella             flexneri             unknown
# SAMEA4428200        Escherichia                 coli             unknown
# SAMN08044485        Escherichia                 coli        PNUSAE010891
#
#               bakta.stats.no_sequences  bakta.stats.size  bakta.stats.gc  \
# #id
# ...

# %%
selection_03 = ecoli.sample(frac=0.03, random_state=seeds[1])
selection_05 = ecoli.sample(frac=0.05, random_state=seeds[2])
selection_08 = ecoli.sample(frac=0.08, random_state=seeds[3])
selection_10 = ecoli.sample(frac=0.10, random_state=seeds[4])

# %%
print(len(set(selection_01.index)),len(set(selection_03.index)),len(set(selection_05.index)),len(set(selection_08.index)),len(set(selection_10.index)))
# Out:
# 891 2674 4457 7131 8914

# %%
references = [selection_01,selection_03,selection_05,selection_08,selection_10]

# %%
query_01 = ecoli[~ecoli.index.isin(selection_01.index)]
query_01
# Out:
#              bakta.genome.genus bakta.genome.species bakta.genome.strain  \
# #id
# SAMD00000649           Shigella          dysenteriae             unknown
# SAMD00000699        Escherichia                 coli             unknown
# SAMD00000724        Escherichia                 coli             unknown
# SAMD00000754        Escherichia                 coli             unknown
# SAMD00000812           Shigella          dysenteriae             unknown
# ...                         ...                  ...                 ...
# SAMN10397942        Escherichia                 coli             unknown
# SAMN10397943        Escherichia                 coli             unknown
# SAMN10397944           Shigella             flexneri             unknown
# SAMN10402087           Shigella               sonnei             unknown
# SAMN10402105           Shigella               sonnei             unknown
#
#               bakta.stats.no_sequences  bakta.stats.size  bakta.stats.gc  \
# #id
# ...

# %%
query_03 = ecoli[~ecoli.index.isin(selection_03.index)]
query_05 = ecoli[~ecoli.index.isin(selection_05.index)]
query_08 = ecoli[~ecoli.index.isin(selection_08.index)]
query_10 = ecoli[~ecoli.index.isin(selection_10.index)]

# %%
print(len(set(query_01.index)),len(set(query_03.index)),len(set(query_05.index)),len(set(query_08.index)),len(set(query_10.index)))
# Out:
# 88245 86462 84679 82005 80222

# %%
queries = [query_01,query_03,query_05,query_08,query_10]

# %% [markdown]
# path_to_references = '/Users/ktruong/workspace/Workspace/experiments/046_selection_strategy_percentage_for_single_species/references/'
# for i,ref in zip(['01','03','05','08','10'],references):
#     filename = path_to_references+f'reference_{i}.txt'
#     values = list(ref.index)
#     with open(filename, "w") as f:
#         for value in values:
#             f.write(f"{value}\n")

# %% [markdown]
# path_to_query = '/Users/ktruong/workspace/Workspace/experiments/046_selection_strategy_percentage_for_single_species/queries/'
# for i,qu in zip(['01','03','05','08','10'],queries):
#     filename = path_to_query+f'query_{i}.txt'
#     values = list(qu.index)
#     with open(filename, "w") as f:
#         for value in values:
#             f.write(f"{value}\n")
