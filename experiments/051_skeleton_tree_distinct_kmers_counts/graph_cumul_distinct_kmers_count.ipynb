# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
series = np.loadtxt('ecoli_cumul.txt', delimiter=",")

# %%
series
# Out:
# array([4.08928225e+06, 5.99315450e+06, 7.32091600e+06, ...,
#        8.72275072e+08, 8.72275072e+08, 8.72275072e+08])

# %%
# X values: 1 to len(series)
x = np.arange(1, len(series) + 1)
y = series

# Plot
plt.plot(x, y)
plt.xlabel("nb_genomes")
plt.ylabel("DKC")
plt.title("Series Plot")
plt.grid(True)
plt.show()
