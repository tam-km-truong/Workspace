# %%
import pandas as pd
import numpy as np
import os
import random
import re

# %%
file_list = pd.read_csv("/Users/ktruong/data/AllTheBacteria/file_list.all.latest.tsv", sep="\t")

# %%
print("length:", file_list.shape[0])
file_list.head()
# Out:
# length: 2440377
#          sample               species_sylph             species_miniphy  \
# 0  SAMN12335635  Achromobacter xylosoxidans  achromobacter_xylosoxidans
# 1  SAMN12335634  Achromobacter xylosoxidans  achromobacter_xylosoxidans
# 2  SAMN12335574  Achromobacter xylosoxidans  achromobacter_xylosoxidans
# 3  SAMN12335579  Achromobacter xylosoxidans  achromobacter_xylosoxidans
# 4  SAMN23768638  Achromobacter xylosoxidans  achromobacter_xylosoxidans
#
#                           filename_in_tar_xz  \
# 0  atb.assembly.r0.2.batch.1/SAMN12335635.fa
# 1  atb.assembly.r0.2.batch.1/SAMN12335634.fa
# 2  atb.assembly.r0.2.batch.1/SAMN12335574.fa
# 3  atb.assembly.r0.2.batch.1/SAMN12335579.fa
# 4  atb.assembly.r0.2.batch.1/SAMN23768638.fa
#
#                              tar_xz  \
# 0  atb.assembly.r0.2.batch.1.tar.xz
# 1  atb.assembly.r0.2.batch.1.tar.xz
# 2  atb.assembly.r0.2.batch.1.tar.xz
# 3  atb.assembly.r0.2.batch.1.tar.xz
# 4  atb.assembly.r0.2.batch.1.tar.xz
#
# ...

# %%
dbin = """
atb.assembly.incr_release.202408.batch.33.tar.xz  atb.assembly.incr_release.202408.batch.48.tar.xz  atb.assembly.r0.2.batch.102.tar.xz  atb.assembly.r0.2.batch.117.tar.xz  atb.assembly.r0.2.batch.132.tar.xz  atb.assembly.r0.2.batch.147.tar.xz
atb.assembly.incr_release.202408.batch.34.tar.xz  atb.assembly.incr_release.202408.batch.49.tar.xz  atb.assembly.r0.2.batch.103.tar.xz  atb.assembly.r0.2.batch.118.tar.xz  atb.assembly.r0.2.batch.133.tar.xz  atb.assembly.r0.2.batch.148.tar.xz
atb.assembly.incr_release.202408.batch.35.tar.xz  atb.assembly.incr_release.202408.batch.50.tar.xz  atb.assembly.r0.2.batch.104.tar.xz  atb.assembly.r0.2.batch.119.tar.xz  atb.assembly.r0.2.batch.134.tar.xz  atb.assembly.r0.2.batch.149.tar.xz
atb.assembly.incr_release.202408.batch.36.tar.xz  atb.assembly.incr_release.202408.batch.51.tar.xz  atb.assembly.r0.2.batch.105.tar.xz  atb.assembly.r0.2.batch.120.tar.xz  atb.assembly.r0.2.batch.135.tar.xz  atb.assembly.r0.2.batch.150.tar.xz
atb.assembly.incr_release.202408.batch.37.tar.xz  atb.assembly.incr_release.202408.batch.52.tar.xz  atb.assembly.r0.2.batch.106.tar.xz  atb.assembly.r0.2.batch.121.tar.xz  atb.assembly.r0.2.batch.136.tar.xz  atb.assembly.r0.2.batch.92.tar.xz
atb.assembly.incr_release.202408.batch.38.tar.xz  atb.assembly.incr_release.202408.batch.53.tar.xz  atb.assembly.r0.2.batch.107.tar.xz  atb.assembly.r0.2.batch.122.tar.xz  atb.assembly.r0.2.batch.137.tar.xz  atb.assembly.r0.2.batch.93.tar.xz
atb.assembly.incr_release.202408.batch.39.tar.xz  atb.assembly.incr_release.202408.batch.54.tar.xz  atb.assembly.r0.2.batch.108.tar.xz  atb.assembly.r0.2.batch.123.tar.xz  atb.assembly.r0.2.batch.138.tar.xz  atb.assembly.r0.2.batch.94.tar.xz
atb.assembly.incr_release.202408.batch.40.tar.xz  atb.assembly.incr_release.202408.batch.55.tar.xz  atb.assembly.r0.2.batch.109.tar.xz  atb.assembly.r0.2.batch.124.tar.xz  atb.assembly.r0.2.batch.139.tar.xz  atb.assembly.r0.2.batch.95.tar.xz
atb.assembly.incr_release.202408.batch.41.tar.xz  atb.assembly.incr_release.202408.batch.56.tar.xz  atb.assembly.r0.2.batch.110.tar.xz  atb.assembly.r0.2.batch.125.tar.xz  atb.assembly.r0.2.batch.140.tar.xz  atb.assembly.r0.2.batch.96.tar.xz
atb.assembly.incr_release.202408.batch.42.tar.xz  atb.assembly.incr_release.202408.batch.57.tar.xz  atb.assembly.r0.2.batch.111.tar.xz  atb.assembly.r0.2.batch.126.tar.xz  atb.assembly.r0.2.batch.141.tar.xz  atb.assembly.r0.2.batch.97.tar.xz
atb.assembly.incr_release.202408.batch.43.tar.xz  atb.assembly.incr_release.202408.batch.58.tar.xz  atb.assembly.r0.2.batch.112.tar.xz  atb.assembly.r0.2.batch.127.tar.xz  atb.assembly.r0.2.batch.142.tar.xz  atb.assembly.r0.2.batch.98.tar.xz
atb.assembly.incr_release.202408.batch.44.tar.xz  atb.assembly.incr_release.202408.batch.59.tar.xz  atb.assembly.r0.2.batch.113.tar.xz  atb.assembly.r0.2.batch.128.tar.xz  atb.assembly.r0.2.batch.143.tar.xz  atb.assembly.r0.2.batch.99.tar.xz
atb.assembly.incr_release.202408.batch.45.tar.xz  atb.assembly.incr_release.202408.batch.60.tar.xz  atb.assembly.r0.2.batch.114.tar.xz  atb.assembly.r0.2.batch.129.tar.xz  atb.assembly.r0.2.batch.144.tar.xz
atb.assembly.incr_release.202408.batch.46.tar.xz  atb.assembly.r0.2.batch.100.tar.xz                atb.assembly.r0.2.batch.115.tar.xz  atb.assembly.r0.2.batch.130.tar.xz  atb.assembly.r0.2.batch.145.tar.xz
atb.assembly.incr_release.202408.batch.47.tar.xz  atb.assembly.r0.2.batch.101.tar.xz                atb.assembly.r0.2.batch.116.tar.xz  atb.assembly.r0.2.batch.131.tar.xz  atb.assembly.r0.2.batch.146.tar.xz
"""

# %%
dbin_1 = 'atb.assembly.r0.2.batch.100.tar.xz'
file_list[file_list['tar_xz'] == dbin_1].groupby('species_miniphy').size()
# Out:
# species_miniphy
# blautiaa_sp900066355           2
# blautiaa_sp900066505           1
# blautiaa_sp900541345           1
# blautiaa_sp900548245           2
# blautiaa_sp900551715           1
#                               ..
# bradyrhizobium_sp003020075    13
# bradyrhizobium_sp004212635     1
# bradyrhizobium_sp005937885     6
# bradyrhizobium_sp009766005     3
# bradyrhizobium_sp011516635     7
# Length: 161, dtype: int64

# %%
fsizes=file_list[['tar_xz','tar_xz_size_MB']]
fsizes = fsizes.drop_duplicates()
fsizes
# Out:
#                                                     tar_xz  tar_xz_size_MB
# 0                         atb.assembly.r0.2.batch.1.tar.xz           32.67
# 285                       atb.assembly.r0.2.batch.2.tar.xz          124.72
# 4285                      atb.assembly.r0.2.batch.3.tar.xz          101.85
# 8285                      atb.assembly.r0.2.batch.4.tar.xz           74.51
# 12285                     atb.assembly.r0.2.batch.5.tar.xz           57.32
# ...                                                    ...             ...
# 2436883  atb.assembly.incr_release.202408.batch.219.tar.xz           56.73
# 2437485  atb.assembly.incr_release.202408.batch.220.tar.xz           22.05
# 2438115  atb.assembly.incr_release.202408.batch.221.tar.xz            8.32
# 2438509  atb.assembly.incr_release.202408.batch.222.tar.xz           47.94
# 2439994  atb.assembly.incr_release.202408.batch.223.tar.xz            6.05
#
# [888 rows x 2 columns]

# %%
fsizes.sum()
# Out:
# tar_xz            atb.assembly.r0.2.batch.1.tar.xzatb.assembly.r...
# tar_xz_size_MB                                             98490.62
# dtype: object

# %%
sizes=fsizes.groupby('tar_xz')

# %%
xz_sizes.sum(axis=1)
# Out:
# tar_xz
# atb.assembly.incr_release.202408.batch.1.tar.xz      245440.00
# atb.assembly.incr_release.202408.batch.10.tar.xz      15413.16
# atb.assembly.incr_release.202408.batch.100.tar.xz    641228.86
# atb.assembly.incr_release.202408.batch.101.tar.xz     32221.56
# atb.assembly.incr_release.202408.batch.102.tar.xz     32164.43
#                                                        ...
# atb.assembly.r0.2.batch.95.tar.xz                    306030.00
# atb.assembly.r0.2.batch.96.tar.xz                    290210.00
# atb.assembly.r0.2.batch.97.tar.xz                    114500.00
# atb.assembly.r0.2.batch.98.tar.xz                    199660.00
# atb.assembly.r0.2.batch.99.tar.xz                    150670.00
# Length: 888, dtype: float64

# %%
batch_groups = file_list.groupby(['tar_xz','species_miniphy']).groups

# %%
batch_groups
# Out:
# {('atb.assembly.incr_release.202408.batch.1.tar.xz', 'acinetobacter_baumannii'): [1932812, 1932813, 1932814, 1932815, 1932816, 1932817, 1932818, 1932819, 1932820, 1932821, 1932822, 1932823, 1932824, 1932825, 1932826, 1932827, 1932828, 1932829, 1932830, 1932831, 1932832, 1932833, 1932834, 1932835, 1932836, 1932837, 1932838, 1932839, 1932840, 1932841, 1932842, 1932843, 1932844, 1932845, 1932846, 1932847, 1932848, 1932849, 1932850, 1932851, 1932852, 1932853, 1932854, 1932855, 1932856, 1932857, 1932858, 1932859, 1932860, 1932861, 1932862, 1932863, 1932864, 1932865, 1932866, 1932867, 1932868, 1932869, 1932870, 1932871, 1932872, 1932873, 1932874, 1932875, 1932876, 1932877, 1932878, 1932879, 1932880, 1932881, 1932882, 1932883, 1932884, 1932885, 1932886, 1932887, 1932888, 1932889, 1932890, 1932891, 1932892, 1932893, 1932894, 1932895, 1932896, 1932897, 1932898, 1932899, 1932900, 1932901, 1932902, 1932903, 1932904, 1932905, 1932906, 1932907, 1932908, 1932909, 1932910, 1932911, ...], ('atb.asse
# ...

# %%
species_sizes = file_list.groupby(['species_miniphy']).size()
type(species_sizes)
# Out:
# pandas.core.series.Series

# %%
dustbin_species =  species_sizes.sort_values(ascending=True)[species_sizes<100]

# %%
dustbin = file_list[file_list['species_miniphy'].isin(dustbin_species.index)]

# %%
dustbin.groupby(['tar_xz']).size()
# Out:
# tar_xz
# atb.assembly.incr_release.202408.batch.33.tar.xz    408
# atb.assembly.incr_release.202408.batch.34.tar.xz    386
# atb.assembly.incr_release.202408.batch.35.tar.xz    351
# atb.assembly.incr_release.202408.batch.36.tar.xz    248
# atb.assembly.incr_release.202408.batch.37.tar.xz    549
#                                                    ...
# atb.assembly.r0.2.batch.95.tar.xz                   660
# atb.assembly.r0.2.batch.96.tar.xz                   644
# atb.assembly.r0.2.batch.97.tar.xz                   169
# atb.assembly.r0.2.batch.98.tar.xz                   448
# atb.assembly.r0.2.batch.99.tar.xz                   653
# Length: 87, dtype: int64

# %%
def extract_prefix_and_number(s):
    match = re.match(r"([A-Z]+)(\d+)", s)
    if not match:
        return None, None
    return match.group(1), int(match.group(2))

def group_accessions_by_range(accessions):
    accessions = sorted(accessions, key=lambda x: extract_prefix_and_number(x))
    grouped = []

    i = 0
    while i < len(accessions):
        start = accessions[i]
        prefix, num = extract_prefix_and_number(start)
        j = i
        while j + 1 < len(accessions):
            next_prefix, next_num = extract_prefix_and_number(accessions[j + 1])
            if next_prefix == prefix and next_num == num + 1:
                j += 1
                num += 1
            else:
                break
        end = accessions[j]
        length = j - i + 1
        if i == j:
            grouped.append(([start], 1))
        else:
            grouped.append(([start, end], length))
        i = j + 1
    return grouped

# Example input
accessions = [
    "SAMD00000344", "SAMD00000345", "SAMD00000355", "SAMD00000550", 
    "SAMD00000552", "SAMN10407504", "SAMN10407505", "SAMN10407506"
]

# Run grouping
groups = group_accessions_by_range(accessions)

# Print results
for group in groups:
    print(group)
# Out:
# (['SAMD00000344', 'SAMD00000345'], 2)
# (['SAMD00000355'], 1)
# (['SAMD00000550'], 1)
# (['SAMD00000552'], 1)
# (['SAMN10407504', 'SAMN10407506'], 3)

# %%
groups_accession = group_accessions_by_range(file_list['sample'])

# %%
groups_accession
# Out:
# [(['SAMD00000344', 'SAMD00000345'], 2),
#  (['SAMD00000355'], 1),
#  (['SAMD00000550'], 1),
#  (['SAMD00000552'], 1),
#  (['SAMD00000562'], 1),
#  (['SAMD00000572'], 1),
#  (['SAMD00000584', 'SAMD00000585'], 2),
#  (['SAMD00000605'], 1),
#  (['SAMD00000611', 'SAMD00000612'], 2),
#  (['SAMD00000644'], 1),
#  (['SAMD00000649'], 1),
#  (['SAMD00000652'], 1),
#  (['SAMD00000665', 'SAMD00000667'], 3),
#  (['SAMD00000669'], 1),
#  (['SAMD00000692'], 1),
#  (['SAMD00000699'], 1),
#  (['SAMD00000724'], 1),
#  (['SAMD00000754'], 1),
#  (['SAMD00000756', 'SAMD00000760'], 5),
#  (['SAMD00000768'], 1),
#  (['SAMD00000798'], 1),
#  (['SAMD00000806'], 1),
#  (['SAMD00000812'], 1),
#  (['SAMD00000816'], 1),
#  (['SAMD00002586', 'SAMD00002593'], 8),
#  (['SAMD00002642'], 1),
#  (['SAMD00002680', 'SAMD00002681'], 2),
#  (['SAMD00002684'], 1),
#  (['SAMD00002686'], 1),
#  (['SAMD00002690', 'SAMD00002691'], 2),
#  (['SAMD00002693'], 1),
#  (['SAMD00002695'], 1),
# ...

# %%
# Convert to DataFrame
rows = []
for group, length in groups_accession:
    if len(group) == 1:
        start = end = group[0]
    else:
        start, end = group
    rows.append({"start": start, "end": end, "length": length})

df_range = pd.DataFrame(rows)
print(df_range)
# Out:
#                start           end  length
# 0       SAMD00000344  SAMD00000345       2
# 1       SAMD00000355  SAMD00000355       1
# 2       SAMD00000550  SAMD00000550       1
# 3       SAMD00000552  SAMD00000552       1
# 4       SAMD00000562  SAMD00000562       1
# ...              ...           ...     ...
# 233877  SAMN42785595  SAMN42785595       1
# 233878  SAMN42786914  SAMN42786914       1
# 233879  SAMN42786917  SAMN42786917       1
# 233880  SAMN42786919  SAMN42786919       1
# 233881  SAMN42786928  SAMN42786928       1
#
# [233882 rows x 3 columns]

# %%
def check_species_consistency(groups, original_df):
    """
    Check if all accessions in each group belong to the same species.

    Args:
        groups (list): List of tuples like ([start, end], length).
        original_df (pd.DataFrame): DataFrame with 'accession' and 'species' columns.

    Returns:
        list of dicts: Each dict includes start, end, length, consistent (bool), and species (if consistent).
    """
    result = []
    
    # Set index to accession for fast lookup
    df = original_df.set_index('sample')
    total = len(groups)
    current=1
    for group, length in groups:
        print(current,'/',total)
        current+=1
        # Expand group: from [start, end] get all accessions between them (inclusive)
        if len(group) == 1:
            accessions = [group[0]]
        else:
            start, end = group
            # Get all accession names in order from the original dataframe
            all_accessions = df.index.tolist()
            try:
                i = all_accessions.index(start)
                j = all_accessions.index(end)
                if i > j:
                    i, j = j, i
                accessions = all_accessions[i:j+1]
            except ValueError:
                accessions = group  # fallback if not found

        species_in_group = df.loc[accessions]['species_sylph'].unique()
        if len(species_in_group) == 1:
            consistent = True
            species = species_in_group[0]
        else:
            consistent = False
            species = None

        result.append({
            "start": group[0],
            "end": group[-1],
            "length": length,
            "consistent": consistent,
            "species": species
        })

    return pd.DataFrame(result)

# %%
# df_consistency = check_species_consistency(groups_accession,file_list)
df_consistency = pd.read_csv('data/allthebacteria_accension_range_data.csv')

# %%
df_consistency.to_csv('data/allthebacteria_accension_range_data.csv')

# %%
size_tf = df_consistency[df_consistency['length']>4].sort_values('length').groupby('consistent').size()

# %%
size_tf[True],size_tf[False]
# Out:
# (45564, 21635)

# %%
len(df_consistency['length'].unique())
# Out:
# 748

# %%
max(df_consistency['length'].unique())
# Out:
# 5150

# %%
df_consistency['length'].mean()
# Out:
# 10.434223240779538

# %%
length = 5

# %%
len(df_consistency[df_consistency['length']>=length]['length'])
# Out:
# 67199

# %%
df_consistency[df_consistency['length']>=length]['length'].sum()
# Out:
# 2205578

# %%
df_consistency[df_consistency['length']>=length]['length'][df_consistency['consistent']==True].sum()
# Out:
# 1460287

# %%
df_consistency[df_consistency['length']>=length]['length'][df_consistency['consistent']==False].sum()
# Out:
# 745291

# %%
df_consistency[df_consistency['length']>=length].sort_values('length').groupby('consistent').size()
# Out:
# consistent
# False    21635
# True     45564
# dtype: int64
