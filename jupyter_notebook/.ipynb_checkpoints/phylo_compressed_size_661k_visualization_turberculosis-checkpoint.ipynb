# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
data = pd.read_csv("./data/csv/661k_compressed_size.csv",header=None, sep = "\t", names = ['size_Mb','name'], index_col = 'name')
data = data.drop('./_md5.txt')
data = data.drop('total')
species_name = [name[2:-11] for name in data.index]
data['species'] = species_name

# %%
data.loc[:,'size_Mb']
# Out:
# name
# ./acinetobacter_baumannii__01.tar.xz                              113
# ./acinetobacter_baumannii__02.tar.xz                               42
# ./acinetobacter_nosocomialis__01.tar.xz                            14
# ./acinetobacter_pittii__01.tar.xz                                  23
# ./actinobacillus_pleuropneumoniae__01.tar.xz                        6
#                                                                  ...
# ./wolbachia_endosymbiont_of_drosophila_melanogaster__01.tar.xz      1
# ./xanthomonas_oryzae__01.tar.xz                                    21
# ./yersinia_enterocolitica__01.tar.xz                               37
# ./yersinia_pestis__01.tar.xz                                        8
# ./yersinia_pseudotuberculosis__01.tar.xz                           14
# Name: size_Mb, Length: 305, dtype: int64

# %%
data.index.values
# Out:
# array(['./acinetobacter_baumannii__01.tar.xz',
#        './acinetobacter_baumannii__02.tar.xz',
#        './acinetobacter_nosocomialis__01.tar.xz',
#        './acinetobacter_pittii__01.tar.xz',
#        './actinobacillus_pleuropneumoniae__01.tar.xz',
#        './aeromonas_hydrophila__01.tar.xz',
#        './aeromonas_salmonicida__01.tar.xz',
#        './aeromonas_veronii__01.tar.xz',
#        './bacillus_anthracis__01.tar.xz', './bacillus_cereus__01.tar.xz',
#        './bacillus_subtilis__01.tar.xz',
#        './bacillus_thuringiensis__01.tar.xz',
#        './bacteroides_fragilis__01.tar.xz',
#        './bordetella_bronchiseptica__01.tar.xz',
#        './bordetella_pertussis__01.tar.xz',
#        './borreliella_burgdorferi__01.tar.xz',
#        './brucella_abortus__01.tar.xz',
#        './brucella_melitensis__01.tar.xz', './brucella_suis__01.tar.xz',
#        './burkholderia_cenocepacia__01.tar.xz',
#        './burkholderia_cepacia__01.tar.xz',
#        './burkholderia_contaminans__01.tar.xz',
#        './burkholderia_gladioli__01.tar.xz',
#        './burkholderia_multivorans__01.tar.xz',
#        './burkholderia_pseudomallei__01.tar.xz',
#        './burkholderia_ubonensis__01.tar.xz',
#        './burkholderia_vietnamiensis__01.tar.xz',
#        './campylobacter_coli__01.tar.xz',
#        './campylobacter_coli__02.tar.xz',
#        './campylobacter_coli__03.tar.xz',
#        './campylobacter_fetus__01.tar.xz',
#        './campylobacter_helveticus__01.tar.xz',
#        './campylobacter_jejuni__01.tar.xz',
#        './campylobacter_jejuni__02.tar.xz',
#        './campylobacter_jejuni__03.tar.xz',
#        './campylobacter_jejuni__04.tar.xz',
#        './campylobacter_jejuni__05.tar.xz',
#        './campylobacter_jejuni__06.tar.xz',
#        './campylobacter_jejuni__07.tar.xz',
#        './campylobacter_jejuni__08.tar.xz',
#        './campylobacter_lari__01.tar.xz',
#        './caulobacter_vibrioides__01.tar.xz',
#        './chlamydia_pecorum__01.tar.xz',
#        './chlamydia_trachomatis__01.tar.xz',
#        './citrobacter_freundii__01.tar.xz',
#        './citrobacter_rodentium__01.tar.xz',
#        './clostridioides_difficile__01.tar.xz',
#        './clostridioides_difficile__02.tar.xz',
#        './clostridioides_difficile__03.tar.xz',
#        './clostridioides_difficile__04.tar.xz',
#        './clostridium_botulinum__01.tar.xz',
#        './clostridium_perfringens__01.tar.xz',
#        './corynebacterium_diphtheriae__01.tar.xz',
#        './cronobacter_sakazakii__01.tar.xz',
#        './cutibacterium_acnes__01.tar.xz',
#        './dichelobacter_nodosus__01.tar.xz', './dustbin__01.tar.xz',
#        './dustbin__02.tar.xz', './dustbin__03.tar.xz',
#        './dustbin__04.tar.xz', './dustbin__05.tar.xz',
#        './dustbin__06.tar.xz', './dustbin__07.tar.xz',
#        './dustbin__08.tar.xz', './dustbin__09.tar.xz',
#        './dustbin__10.tar.xz', './dustbin__11.tar.xz',
#        './dustbin__12.tar.xz', './dustbin__13.tar.xz',
#        './dustbin__14.tar.xz', './dustbin__15.tar.xz',
#        './dustbin__16.tar.xz', './dustbin__17.tar.xz',
#        './dustbin__18.tar.xz', './dustbin__19.tar.xz',
#        './dustbin__20.tar.xz', './dustbin__21.tar.xz',
#        './dustbin__22.tar.xz', './elizabethkingia_anophelis__01.tar.xz',
#        './enterobacter_cloacae__01.tar.xz',
#        './enterobacter_hormaechei__01.tar.xz',
#        './enterococcus_faecalis__01.tar.xz',
#        './enterococcus_faecium__01.tar.xz',
#        './enterococcus_faecium__02.tar.xz',
#        './enterococcus_faecium__03.tar.xz',
#        './enterococcus_hirae__01.tar.xz',
#        './erysipelothrix_rhusiopathiae__01.tar.xz',
#        './escherichia_albertii__01.tar.xz',
#        './escherichia_coli__01.tar.xz', './escherichia_coli__02.tar.xz',
#        './escherichia_coli__03.tar.xz', './escherichia_coli__04.tar.xz',
#        './escherichia_coli__05.tar.xz', './escherichia_coli__06.tar.xz',
#        './escherichia_coli__07.tar.xz', './escherichia_coli__08.tar.xz',
#        './escherichia_coli__09.tar.xz', './escherichia_coli__10.tar.xz',
#        './escherichia_coli__11.tar.xz', './escherichia_coli__12.tar.xz',
#        './escherichia_coli__13.tar.xz', './escherichia_coli__14.tar.xz',
#        './escherichia_coli__15.tar.xz', './escherichia_coli__16.tar.xz',
#        './escherichia_coli__17.tar.xz', './escherichia_coli__18.tar.xz',
#        './escherichia_coli__19.tar.xz', './escherichia_coli__20.tar.xz',
#        './escherichia_coli__21.tar.xz', './escherichia_coli__22.tar.xz',
#        './escherichia_coli__23.tar.xz', './eubacterium_hallii__01.tar.xz',
#        './flavobacterium_johnsoniae__01.tar.xz',
#        './glaesserella_parasuis__01.tar.xz',
#        './haemophilus_influenzae__01.tar.xz',
#        './helicobacter_pylori__01.tar.xz',
#        './hungateiclostridium_thermocellum__01.tar.xz',
#        './klebsiella_aerogenes__01.tar.xz',
#        './klebsiella_oxytoca__01.tar.xz',
#        './klebsiella_pneumoniae__01.tar.xz',
#        './klebsiella_pneumoniae__02.tar.xz',
#        './klebsiella_pneumoniae__03.tar.xz',
#        './klebsiella_pneumoniae__04.tar.xz',
#        './klebsiella_quasipneumoniae__01.tar.xz',
#        './klebsiella_variicola__01.tar.xz',
#        './lactobacillus_casei__01.tar.xz',
#        './lactobacillus_plantarum__01.tar.xz',
#        './lactobacillus_rhamnosus__01.tar.xz',
#        './lactobacillus_salivarius__01.tar.xz',
#        './lactococcus_lactis__01.tar.xz',
#        './legionella_pneumophila__01.tar.xz',
#        './leptospira_interrogans__01.tar.xz',
#        './listeria_monocytogenes__01.tar.xz',
#        './listeria_monocytogenes__02.tar.xz',
#        './listeria_monocytogenes__03.tar.xz',
#        './listeria_monocytogenes__04.tar.xz',
#        './listeria_monocytogenes__05.tar.xz',
#        './listeria_monocytogenes__06.tar.xz',
#        './listeria_monocytogenes__07.tar.xz',
#        './mannheimia_haemolytica__01.tar.xz',
#        './mesorhizobium_ciceri__01.tar.xz',
#        './moraxella_catarrhalis__01.tar.xz',
#        './morganella_morganii__01.tar.xz',
#        './mycobacterium_avium__01.tar.xz',
#        './mycobacterium_bovis__01.tar.xz',
#        './mycobacterium_chimaera__01.tar.xz',
#        './mycobacterium_intracellulare__01.tar.xz',
#        './mycobacterium_kansasii__01.tar.xz',
#        './mycobacterium_tuberculosis__01.tar.xz',
#        './mycobacterium_tuberculosis__02.tar.xz',
#        './mycobacterium_tuberculosis__03.tar.xz',
#        './mycobacterium_tuberculosis__04.tar.xz',
#        './mycobacterium_tuberculosis__05.tar.xz',
#        './mycobacterium_tuberculosis__06.tar.xz',
#        './mycobacterium_tuberculosis__07.tar.xz',
#        './mycobacterium_tuberculosis__08.tar.xz',
#        './mycobacterium_tuberculosis__09.tar.xz',
#        './mycobacterium_tuberculosis__10.tar.xz',
#        './mycobacterium_tuberculosis__11.tar.xz',
#        './mycobacterium_tuberculosis__12.tar.xz',
#        './mycobacterium_tuberculosis__13.tar.xz',
#        './mycobacterium_ulcerans__01.tar.xz',
#        './mycobacteroides_abscessus__01.tar.xz',
#        './mycobacteroides_chelonae__01.tar.xz',
#        './mycolicibacterium_smegmatis__01.tar.xz',
#        './mycoplasma_bovis__01.tar.xz',
#        './mycoplasma_hyopneumoniae__01.tar.xz',
#        './mycoplasma_pneumoniae__01.tar.xz',
#        './neisseria_gonorrhoeae__01.tar.xz',
#        './neisseria_gonorrhoeae__02.tar.xz',
#        './neisseria_gonorrhoeae__03.tar.xz',
#        './neisseria_lactamica__01.tar.xz',
#        './neisseria_meningitidis__01.tar.xz',
#        './neisseria_meningitidis__02.tar.xz',
#        './neisseria_meningitidis__03.tar.xz',
#        './neisseria_meningitidis__04.tar.xz',
#        './neisseria_meningitidis__05.tar.xz',
#        './neisseria_subflava__01.tar.xz', './oenococcus_oeni__01.tar.xz',
#        './paenibacillus_larvae__01.tar.xz',
#        './pasteurella_multocida__01.tar.xz',
#        './porphyromonas_gingivalis__01.tar.xz',
#        './prochlorococcus_marinus__01.tar.xz',
#        './proteus_mirabilis__01.tar.xz',
#        './pseudomonas_aeruginosa__01.tar.xz',
#        './pseudomonas_aeruginosa__02.tar.xz',
#        './pseudomonas_fluorescens__01.tar.xz',
#        './pseudomonas_putida__01.tar.xz',
#        './pseudomonas_syringae__01.tar.xz',
#        './rhizobium_leguminosarum__01.tar.xz',
#        './roseburia_hominis__01.tar.xz',
#        './salmonella_bongori__01.tar.xz',
#        './salmonella_enterica__01.tar.xz',
#        './salmonella_enterica__02.tar.xz',
#        './salmonella_enterica__03.tar.xz',
#        './salmonella_enterica__04.tar.xz',
#        './salmonella_enterica__05.tar.xz',
#        './salmonella_enterica__06.tar.xz',
#        './salmonella_enterica__07.tar.xz',
#        './salmonella_enterica__08.tar.xz',
#        './salmonella_enterica__09.tar.xz',
#        './salmonella_enterica__10.tar.xz',
#        './salmonella_enterica__11.tar.xz',
#        './salmonella_enterica__12.tar.xz',
#        './salmonella_enterica__13.tar.xz',
#        './salmonella_enterica__14.tar.xz',
#        './salmonella_enterica__15.tar.xz',
#        './salmonella_enterica__16.tar.xz',
#        './salmonella_enterica__17.tar.xz',
#        './salmonella_enterica__18.tar.xz',
#        './salmonella_enterica__19.tar.xz',
#        './salmonella_enterica__20.tar.xz',
#        './salmonella_enterica__21.tar.xz',
#        './salmonella_enterica__22.tar.xz',
#        './salmonella_enterica__23.tar.xz',
#        './salmonella_enterica__24.tar.xz',
#        './salmonella_enterica__25.tar.xz',
#        './salmonella_enterica__26.tar.xz',
#        './salmonella_enterica__27.tar.xz',
#        './salmonella_enterica__28.tar.xz',
#        './salmonella_enterica__29.tar.xz',
#        './salmonella_enterica__30.tar.xz',
#        './salmonella_enterica__31.tar.xz',
#        './salmonella_enterica__32.tar.xz',
#        './salmonella_enterica__33.tar.xz',
#        './salmonella_enterica__34.tar.xz',
#        './salmonella_enterica__35.tar.xz',
#        './salmonella_enterica__36.tar.xz',
#        './salmonella_enterica__37.tar.xz',
#        './salmonella_enterica__38.tar.xz',
#        './salmonella_enterica__39.tar.xz',
#        './salmonella_enterica__40.tar.xz',
#        './salmonella_enterica__41.tar.xz',
#        './salmonella_enterica__42.tar.xz',
#        './salmonella_enterica__43.tar.xz',
#        './salmonella_enterica__44.tar.xz',
#        './salmonella_enterica__45.tar.xz',
#        './salmonella_enterica__46.tar.xz',
#        './serratia_marcescens__01.tar.xz',
#        './shigella_dysenteriae__01.tar.xz',
#        './shigella_flexneri__01.tar.xz',
#        './sinorhizobium_meliloti__01.tar.xz',
#        './staphylococcus_agnetis__01.tar.xz',
#        './staphylococcus_argenteus__01.tar.xz',
#        './staphylococcus_aureus__01.tar.xz',
#        './staphylococcus_aureus__02.tar.xz',
#        './staphylococcus_aureus__03.tar.xz',
#        './staphylococcus_aureus__04.tar.xz',
#        './staphylococcus_aureus__05.tar.xz',
#        './staphylococcus_aureus__06.tar.xz',
#        './staphylococcus_aureus__07.tar.xz',
#        './staphylococcus_aureus__08.tar.xz',
#        './staphylococcus_aureus__09.tar.xz',
#        './staphylococcus_aureus__10.tar.xz',
#        './staphylococcus_aureus__11.tar.xz',
#        './staphylococcus_aureus__12.tar.xz',
#        './staphylococcus_aureus__13.tar.xz',
#        './staphylococcus_capitis__01.tar.xz',
#        './staphylococcus_epidermidis__01.tar.xz',
#        './staphylococcus_haemolyticus__01.tar.xz',
#        './staphylococcus_pseudintermedius__01.tar.xz',
#        './staphylococcus_sciuri__01.tar.xz',
#        './stenotrophomonas_maltophilia__01.tar.xz',
#        './streptococcus_agalactiae__01.tar.xz',
#        './streptococcus_agalactiae__02.tar.xz',
#        './streptococcus_agalactiae__03.tar.xz',
#        './streptococcus_dysgalactiae__01.tar.xz',
#        './streptococcus_equi__01.tar.xz',
#        './streptococcus_mitis__01.tar.xz',
#        './streptococcus_mutans__01.tar.xz',
#        './streptococcus_oralis__01.tar.xz',
#        './streptococcus_pneumoniae__01.tar.xz',
#        './streptococcus_pneumoniae__02.tar.xz',
#        './streptococcus_pneumoniae__03.tar.xz',
#        './streptococcus_pneumoniae__04.tar.xz',
#        './streptococcus_pneumoniae__05.tar.xz',
#        './streptococcus_pneumoniae__06.tar.xz',
#        './streptococcus_pneumoniae__07.tar.xz',
#        './streptococcus_pneumoniae__08.tar.xz',
#        './streptococcus_pneumoniae__09.tar.xz',
#        './streptococcus_pneumoniae__10.tar.xz',
#        './streptococcus_pneumoniae__11.tar.xz',
#        './streptococcus_pneumoniae__12.tar.xz',
#        './streptococcus_pneumoniae__13.tar.xz',
#        './streptococcus_pseudopneumoniae__01.tar.xz',
#        './streptococcus_pyogenes__01.tar.xz',
#        './streptococcus_pyogenes__02.tar.xz',
#        './streptococcus_pyogenes__03.tar.xz',
#        './streptococcus_pyogenes__04.tar.xz',
#        './streptococcus_pyogenes__05.tar.xz',
#        './streptococcus_sp_group_b__01.tar.xz',
#        './streptococcus_suis__01.tar.xz',
#        './streptococcus_uberis__01.tar.xz',
#        './taylorella_equigenitalis__01.tar.xz',
#        './treponema_pallidum__01.tar.xz', './vibrio_cholerae__01.tar.xz',
#        './vibrio_cholerae__02.tar.xz',
#        './vibrio_parahaemolyticus__01.tar.xz',
#        './vibrio_shilonii__01.tar.xz', './vibrio_vulnificus__01.tar.xz',
#        './wolbachia_endosymbiont_of_drosophila_melanogaster__01.tar.xz',
#        './xanthomonas_oryzae__01.tar.xz',
#        './yersinia_enterocolitica__01.tar.xz',
#        './yersinia_pestis__01.tar.xz',
#        './yersinia_pseudotuberculosis__01.tar.xz'], dtype=object)

# %%
fig, ax = plt.subplots(figsize=(15, 5))

df_plot = data.loc[:,'size_Mb']

files = df_plot.index.values
sizes = df_plot.values
# bar_labels = ['red', 'blue', '_red', 'orange']
# bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

# ax.bar(files, counts, label=bar_labels, color=bar_colors)
ax.bar(files, sizes,width=1, ec = 'white')

ax.set_ylabel('Size in Mb')
ax.set_title('Compressed genome files size')
ax.set_xlabel('Batches')
plt.xticks([])

plt.show()

# %%
df_group_by_species = data.groupby('species').sum()
df_group_by_species = df_group_by_species.sort_values(by = 'size_Mb',ascending = False)
simple_colors_9500 = {
    "Red": "#e6194B",
    "Green": "#3cb44b",
    "Yellow": "#ffe119",
    "Blue": "#4363d8",
    "Orange": "#f58231",
    "Purple": "#911eb4",
    "Cyan": "#42d4f4",
    "Magenta": "#f032e6",
    "Lime": "#bfef45",
    "Pink": "#fabed4",
    "Teal": "#469990",
    "Lavender": "#dcbeff",
    "Brown": "#9A6324",
    "Beige": "#fffac8",
    "Maroon": "#800000",
    "Mint": "#aaffc3",
    "Olive": "#808000",
    "Apricot": "#ffd8b1",
    "Navy": "#000075",
    "Grey": "#a9a9a9",
    "Black": "#000000",
    "White": "#ffffff",
}

selected_colors = list(simple_colors_9500.keys())[:10]
print(selected_colors)
colors = selected_colors[:10] + ['black']*(len(df_group_by_species)-10)
df_group_by_species['color'] = colors
# Out:
# ['Red', 'Green', 'Yellow', 'Blue', 'Orange', 'Purple', 'Cyan', 'Magenta', 'Lime', 'Pink']

# %%
df_group_by_species.head(10)
# Out:
#                             size_Mb    color
# species
# dustbin                        9190      Red
# salmonella_enterica            4816    Green
# escherichia_coli               4404   Yellow
# mycobacterium_tuberculosis     1190     Blue
# klebsiella_pneumoniae           724   Orange
# streptococcus_pneumoniae        722   Purple
# staphylococcus_aureus           633     Cyan
# clostridioides_difficile        377  Magenta
# pseudomonas_aeruginosa          343     Lime
# listeria_monocytogenes          296     Pink

# %%
colors_dict = dict(map(lambda i,j : (i,j) , df_group_by_species.index,colors))
data['colors'] = data['species'].map(colors_dict)
[color.lower() for color in data.loc[:,'colors'].values]
list(df_group_by_species.index.values[:10]) + ['other']
# Out:
# ['dustbin',
#  'salmonella_enterica',
#  'escherichia_coli',
#  'mycobacterium_tuberculosis',
#  'klebsiella_pneumoniae',
#  'streptococcus_pneumoniae',
#  'staphylococcus_aureus',
#  'clostridioides_difficile',
#  'pseudomonas_aeruginosa',
#  'listeria_monocytogenes',
#  'other']

# %%
fig, ax = plt.subplots(figsize=(15, 5))

df_plot = data.loc[:,'size_Mb']

files = df_plot.index.values
sizes = df_plot.values

bar_colors = [color.lower() for color in data.loc[:,'colors'].values]

# ax.bar(files, counts, label=bar_labels, color=bar_colors)
ax.bar(files, sizes, color=bar_colors,width=1, ec = 'white')

ax.set_ylabel('size in Mb')
ax.set_xlabel('Batches')
ax.set_title('Color coded - Top 10 species')

species_colors = colors
labels = list(df_group_by_species.index.values[:10]) + ['other']
lines = [Line2D([0], [0], color=c, linewidth=3, linestyle='-') for c in species_colors]
ax.legend(lines,labels)
plt.xticks([])

plt.show()

# %%
data_tuber = data[data.index.str.contains('mycobacterium_tuberculosis')]

# %%
data_tuber['size_Mb']
# Out:
# name
# ./mycobacterium_tuberculosis__01.tar.xz     89
# ./mycobacterium_tuberculosis__02.tar.xz     58
# ./mycobacterium_tuberculosis__03.tar.xz    146
# ./mycobacterium_tuberculosis__04.tar.xz     81
# ./mycobacterium_tuberculosis__05.tar.xz     76
# ./mycobacterium_tuberculosis__06.tar.xz     90
# ./mycobacterium_tuberculosis__07.tar.xz    160
# ./mycobacterium_tuberculosis__08.tar.xz    111
# ./mycobacterium_tuberculosis__09.tar.xz     45
# ./mycobacterium_tuberculosis__10.tar.xz    116
# ./mycobacterium_tuberculosis__11.tar.xz     56
# ./mycobacterium_tuberculosis__12.tar.xz    108
# ./mycobacterium_tuberculosis__13.tar.xz     54
# Name: size_Mb, dtype: int64
