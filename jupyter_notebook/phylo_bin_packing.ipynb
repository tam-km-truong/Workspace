# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/bakrep-export-aureus.tsv",sep = "\t",low_memory=False)

# %%
df.head()
# Out:
#             #id bakta.genome.genus bakta.genome.species bakta.genome.strain  \
# 0  SAMD00006357     Staphylococcus               aureus             unknown
# 1  SAMD00009488     Staphylococcus               aureus             unknown
# 2  SAMD00009489     Staphylococcus               aureus             unknown
# 3  SAMD00009490     Staphylococcus               aureus             unknown
# 4  SAMD00009491        Leuconostoc              citreum             unknown
#
#    bakta.stats.no_sequences  bakta.stats.size  bakta.stats.gc  \
# 0                        92           2766258        0.327385
# 1                       573           2782254        0.326929
# 2                       577           2872920        0.326815
# 3                       503           2691639        0.327196
# 4                       543           2672542        0.328131
#
#    bakta.stats.n_ratio  bakta.stats.n50  bakta.stats.coding_ratio  ...  \
# 0                  0.0            97486                  0.840740  ...
# 1                  0.0             9156                  0.743907  ...
# 2                  0.0             8419                  0.754526  ...
# 3                  0.0             9105                  0.753533  ...
# 4                  0.0             8461                  0.738899  ...
#
#   metadata.location metadata.project_name metadata.sample_alias  \
# 0               NaN                   NaN          SAMD00006357
# 1               NaN                   NaN          SAMD00009488
# 2               NaN                   NaN          SAMD00009489
# 3               NaN                   NaN          SAMD00009490
# 4               NaN                   NaN          SAMD00009491
#
#   metadata.secondary_sample_accession metadata.secondary_study_accession  \
# 0                           DRS013787                          DRP001363
# 1                           DRS015697                          DRP002237
# 2                           DRS015698                          DRP002237
# 3                           DRS015700                          DRP002237
# 4                           DRS015694                          DRP002237
#
#   metadata.serotype metadata.serovar metadata.strain  \
# 0               NaN              NaN             NaN
# 1               NaN              NaN             NaN
# 2               NaN              NaN             NaN
# 3               NaN              NaN             NaN
# 4               NaN              NaN             NaN
#
#    metadata.study_accession  metadata.submission_accession
# 0                 PRJDB2070                      DRA001292
# 1                 PRJDB1667                      DRA002159
# 2                 PRJDB1667                      DRA002159
# 3                 PRJDB1667                      DRA002159
# 4                 PRJDB1667                      DRA002159
#
# [5 rows x 42 columns]

# %%
df.columns
# Out:
# Index(['#id', 'bakta.genome.genus', 'bakta.genome.species',
#        'bakta.genome.strain', 'bakta.stats.no_sequences', 'bakta.stats.size',
#        'bakta.stats.gc', 'bakta.stats.n_ratio', 'bakta.stats.n50',
#        'bakta.stats.coding_ratio', 'gtdbtk.classification.domain',
#        'gtdbtk.classification.phylum', 'gtdbtk.classification.class',
#        'gtdbtk.classification.order', 'gtdbtk.classification.family',
#        'gtdbtk.classification.genus', 'gtdbtk.classification.species',
#        'mlst.sequence_type', 'checkm2.quality.completeness',
#        'checkm2.quality.contamination', 'metadata.accession',
#        'metadata.collected_by', 'metadata.collection_date', 'metadata.country',
#        'metadata.host', 'metadata.host_sex', 'metadata.host_status',
#        'metadata.host_tax_id', 'metadata.instrument_model',
#        'metadata.instrument_platform', 'metadata.isolate',
#        'metadata.isolation_source', 'metadata.location',
#        'metadata.project_name', 'metadata.sample_alias',
#        'metadata.secondary_sample_accession',
#        'metadata.secondary_study_accession', 'metadata.serotype',
#        'metadata.serovar', 'metadata.strain', 'metadata.study_accession',
#        'metadata.submission_accession'],
#       dtype='object')

# %%
df[['gtdbtk.classification.species','bakta.stats.size']]
# Out:
#       gtdbtk.classification.species  bakta.stats.size
# 0             Staphylococcus aureus           2766258
# 1             Staphylococcus aureus           2782254
# 2             Staphylococcus aureus           2872920
# 3             Staphylococcus aureus           2691639
# 4             Staphylococcus aureus           2672542
# ...                             ...               ...
# 47717         Staphylococcus aureus           2897701
# 47718         Staphylococcus aureus           2882847
# 47719         Staphylococcus aureus           2841214
# 47720         Staphylococcus aureus           2885291
# 47721         Staphylococcus aureus           2845654
#
# [47722 rows x 2 columns]

# %%
df.boxplot(column='bakta.stats.size', by='gtdbtk.classification.species')
# Out:
# <Axes: title={'center': 'bakta.stats.size'}, xlabel='gtdbtk.classification.species'>

# %%
df.boxplot(column='bakta.stats.size')
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.displot(df[['bakta.stats.size']], kde=True, bins=15)

# %%
def firstFit(weight, n, c):
    
    # Initialize result (Count of bins)
    res = 0
    
    # Create an array to store remaining space in bins
    # there can be at most n bins
    bin_rem = [0]*n
    
    # Place items one by one
    for i in range(n):
      
        # Find the first bin that can accommodate
        # weight[i]
        j = 0
        while( j < res):
            if (bin_rem[j] >= weight[i]):
                bin_rem[j] = bin_rem[j] - weight[i]
                break
            j+=1
            
        # If no bin could accommodate weight[i]
        if (j == res):
            bin_rem[res] = c - weight[i]
            res= res+1
    return res

# %%
weight = list(df['bakta.stats.size'].values)
n = len(weight)
c = 3000000000

# %%
firstFit(weight, n, c)
# Out:
# 45

# %%
import prtpy

# %%
capacity = 256000000

# %%
bins =  prtpy.pack(algorithm=prtpy.packing.first_fit, binsize=capacity, items=weight)

# %%
len(bins)
# Out:
# 528

# %%
res_ff =  [sum(l) for l in bins]

# %%
bins =  prtpy.pack(algorithm=prtpy.packing.first_fit_decreasing, binsize=capacity, items=weight)

# %%
len(bins)
# Out:
# 528

# %%
res_ffd =  [sum(l) for l in bins]

# %%
df_res = pd.DataFrame((res_ffd), columns= ['first_fit_descending'])

# %%
df_res['first_fit'] = res_ff

# %%
df_res
# Out:
#      first_fit_descending  first_fit
# 0               255993713  255874052
# 1               255979597  255954465
# 2               255986369  255999752
# 3               255994297  255631529
# 4               255990694  255967956
# ..                    ...        ...
# 523             255403974  255990019
# 524             254890150  255977913
# 525             254053862  254480125
# 526             255998267  253563541
# 527              76538216  116963537
#
# [528 rows x 2 columns]

# %%
greedy = prtpy.partition(algorithm=prtpy.partitioning.greedy, numbins=528, items=weight, outputtype=prtpy.out.Sums)

# %%
greedy
# Out:
# [254906461.0,
#  254701932.0,
#  254002591.0,
#  255551840.0,
#  255134357.0,
#  254450864.0,
#  253699034.0,
#  253691010.0,
#  255754919.0,
#  255788806.0,
#  255771420.0,
#  255667057.0,
#  255189649.0,
#  255150155.0,
#  255075674.0,
#  254922976.0,
#  254916784.0,
#  254893283.0,
#  254783063.0,
#  254731420.0,
#  254714107.0,
#  254707325.0,
#  254682018.0,
#  254631084.0,
#  254618403.0,
#  254591278.0,
#  254565654.0,
#  254509419.0,
#  254496694.0,
#  254465118.0,
#  254434041.0,
#  254332077.0,
#  254227292.0,
#  254225762.0,
#  254217604.0,
#  254195916.0,
#  254174501.0,
#  254111887.0,
#  254000627.0,
#  253992407.0,
#  253990363.0,
#  253932391.0,
#  253917490.0,
#  253900801.0,
#  253900825.0,
#  253889384.0,
#  253887289.0,
#  253867908.0,
#  253862654.0,
#  253803263.0,
#  253794924.0,
#  253609811.0,
#  253609404.0,
#  253589925.0,
#  254019286.0,
#  254402710.0,
#  255427164.0,
#  255888824.0,
#  255943777.0,
#  255922755.0,
#  255897893.0,
#  255894012.0,
#  255867580.0,
#  255846888.0,
#  255835477.0,
#  255771805.0,
#  255762910.0,
#  255744596.0,
#  255703974.0,
#  255686188.0,
#  255684754.0,
#  255683457.0,
#  255677077.0,
#  255667043.0,
#  255655703.0,
#  255655345.0,
#  255655670.0,
#  255648592.0,
#  255648669.0,
#  255637584.0,
#  255630976.0,
#  255626486.0,
#  255615443.0,
#  255592566.0,
#  255587234.0,
#  255570672.0,
#  255545996.0,
#  255537835.0,
#  255534165.0,
#  255532384.0,
#  255507178.0,
#  255501055.0,
#  255497748.0,
#  255487389.0,
#  255448900.0,
#  255447889.0,
#  255433148.0,
#  255413134.0,
#  255409209.0,
#  255372488.0,
#  255371515.0,
#  255336140.0,
#  255336372.0,
#  255317901.0,
#  255295499.0,
#  255280307.0,
#  255226810.0,
#  255214407.0,
#  255197608.0,
#  255189051.0,
#  255173476.0,
#  255136377.0,
#  255121385.0,
#  255108953.0,
#  255109091.0,
#  255049938.0,
#  255024759.0,
#  254901266.0,
#  254836268.0,
#  254826842.0,
#  254791099.0,
#  254762717.0,
#  254751711.0,
#  254739237.0,
#  254710641.0,
#  254707284.0,
#  254707299.0,
#  254705702.0,
#  254703576.0,
#  254699873.0,
#  254654803.0,
#  254638406.0,
#  254617521.0,
#  254566717.0,
#  254486603.0,
#  254478050.0,
#  254464807.0,
#  254435150.0,
#  254424414.0,
#  254407728.0,
#  254405821.0,
#  254402976.0,
#  254379279.0,
#  254336089.0,
#  254335666.0,
#  254319281.0,
#  254314125.0,
#  254309327.0,
#  254304908.0,
#  254296521.0,
#  254287740.0,
#  254283096.0,
#  254280889.0,
#  254270024.0,
#  254257594.0,
#  254254911.0,
#  254251141.0,
#  254244827.0,
#  254242242.0,
#  254233522.0,
#  254217568.0,
#  254197190.0,
#  254191556.0,
#  254173409.0,
#  254142737.0,
#  254135480.0,
#  254120993.0,
#  254106654.0,
#  254092536.0,
#  254081039.0,
#  254075888.0,
#  254061973.0,
#  254059889.0,
#  254038343.0,
#  254031096.0,
#  254020199.0,
#  254017195.0,
#  254010140.0,
#  254001862.0,
#  253989385.0,
#  253975389.0,
#  253953438.0,
#  253945178.0,
#  253932392.0,
#  253924437.0,
#  253916585.0,
#  253910127.0,
#  253901086.0,
#  253901026.0,
#  253900777.0,
#  253900900.0,
#  253893403.0,
#  253893492.0,
#  253891739.0,
#  253891676.0,
#  253881986.0,
#  253876419.0,
#  253876373.0,
#  253876228.0,
#  253876255.0,
#  253871761.0,
#  253865583.0,
#  253862581.0,
#  253862539.0,
#  253860833.0,
#  253856552.0,
#  253845482.0,
#  253838805.0,
#  253838609.0,
#  253838166.0,
#  253837200.0,
#  253832232.0,
#  253831022.0,
#  253829993.0,
#  253822962.0,
#  253816885.0,
#  253815704.0,
#  253813021.0,
#  253811926.0,
#  253806724.0,
#  253804059.0,
#  253803985.0,
#  253803308.0,
#  253799869.0,
#  253791622.0,
#  253791520.0,
#  253786955.0,
#  253784893.0,
#  253777480.0,
#  253777107.0,
#  253775154.0,
#  253770656.0,
#  253770573.0,
#  253770113.0,
#  253768962.0,
#  253765176.0,
#  253765161.0,
#  253746679.0,
#  253738027.0,
#  253731057.0,
#  253724943.0,
#  253720541.0,
#  253702433.0,
#  253699007.0,
#  253681351.0,
#  253678989.0,
#  253678984.0,
#  253678953.0,
#  253671840.0,
#  253666910.0,
#  253657757.0,
#  253647974.0,
#  253646106.0,
#  253637022.0,
#  253635113.0,
#  253621329.0,
#  253621298.0,
#  253607961.0,
#  253606526.0,
#  253578607.0,
#  253571271.0,
#  253789149.0,
#  253978189.0,
#  254007318.0,
#  254022035.0,
#  254033030.0,
#  254070267.0,
#  254089963.0,
#  254156113.0,
#  254159779.0,
#  254180297.0,
#  254209221.0,
#  254290646.0,
#  254324127.0,
#  254357389.0,
#  254352517.0,
#  254355035.0,
#  254371065.0,
#  254391551.0,
#  254408860.0,
#  254411551.0,
#  254401031.0,
#  254406683.0,
#  254466728.0,
#  254484985.0,
#  254493749.0,
#  254551475.0,
#  254518297.0,
#  254569359.0,
#  254569571.0,
#  254585118.0,
#  254584382.0,
#  254593049.0,
#  254619108.0,
#  254662152.0,
#  254684211.0,
#  254660149.0,
#  254691610.0,
#  254695804.0,
#  254824350.0,
#  254827715.0,
#  254831078.0,
#  254870272.0,
#  254879213.0,
#  254906075.0,
#  254922418.0,
#  254924300.0,
#  254930266.0,
#  254985284.0,
#  254997169.0,
#  254994289.0,
#  255028030.0,
#  255178660.0,
#  255114080.0,
#  255136181.0,
#  255186175.0,
#  255062952.0,
#  255073969.0,
#  255087877.0,
#  255153899.0,
#  255215398.0,
#  255269794.0,
#  255270571.0,
#  255269403.0,
#  255305156.0,
#  255307812.0,
#  255312170.0,
#  255313863.0,
#  255314622.0,
#  255330877.0,
#  255344577.0,
#  255369878.0,
#  255385914.0,
#  255423582.0,
#  255430541.0,
#  255433442.0,
#  255446531.0,
#  255504775.0,
#  255457418.0,
#  255507117.0,
#  255515472.0,
#  255520956.0,
#  255524658.0,
#  255529635.0,
#  255531392.0,
#  255531086.0,
#  255587681.0,
#  255531078.0,
#  255596398.0,
#  255604574.0,
#  255605419.0,
#  255596598.0,
#  255599780.0,
#  255603017.0,
#  255620070.0,
#  255614456.0,
#  255636005.0,
#  255643594.0,
#  255655211.0,
#  255660753.0,
#  255670242.0,
#  255684538.0,
#  255682988.0,
#  255685774.0,
#  255685274.0,
#  255685153.0,
#  255688853.0,
#  255696475.0,
#  255696806.0,
#  255698060.0,
#  255701267.0,
#  255704145.0,
#  255713647.0,
#  255747555.0,
#  255756028.0,
#  255719173.0,
#  255713999.0,
#  255713364.0,
#  255742250.0,
#  255747097.0,
#  255728343.0,
#  255713301.0,
#  255737243.0,
#  255754600.0,
#  255715461.0,
#  255766444.0,
#  255759743.0,
#  255754876.0,
#  255760004.0,
#  255761153.0,
#  255759225.0,
#  255769099.0,
#  255768463.0,
#  255767591.0,
#  255773523.0,
#  255775351.0,
#  255777130.0,
#  255775518.0,
#  255779831.0,
#  255781179.0,
#  255789434.0,
#  255794575.0,
#  255791245.0,
#  255793921.0,
#  255863503.0,
#  255874964.0,
#  255884569.0,
#  255926873.0,
#  255927020.0,
#  255927146.0,
#  255946483.0,
#  255886934.0,
#  255895348.0,
#  255904709.0,
#  255944615.0,
#  255883527.0,
#  255944691.0,
#  255828826.0,
#  255935543.0,
#  255927030.0,
#  255947557.0,
#  255806938.0,
#  255927091.0,
#  255877684.0,
#  255900253.0,
#  255900055.0,
#  255803057.0,
#  255920080.0,
#  255802369.0,
#  255885598.0,
#  255909915.0,
#  255813502.0,
#  255871956.0,
#  255945981.0,
#  255944406.0,
#  255912186.0,
#  255943158.0,
#  255884678.0,
#  255946921.0,
#  255927004.0,
#  255925827.0,
#  255830512.0,
#  255869518.0,
#  255948289.0,
#  255829084.0,
#  255947524.0,
#  255866688.0,
#  255917251.0,
#  255887149.0,
#  255937671.0,
#  255913829.0,
#  255944522.0,
#  255852484.0,
#  255931950.0,
#  255911095.0,
#  255872960.0,
#  255857717.0,
#  255928408.0,
#  255875346.0,
#  255814487.0,
#  255942248.0,
#  255831271.0,
#  255813765.0,
#  255884168.0,
#  255887204.0,
#  255938345.0,
#  255944273.0,
#  255946301.0,
#  255940100.0,
#  255907906.0,
#  255914878.0,
#  255794484.0,
#  255928238.0,
#  255797275.0,
#  255926536.0,
#  255888835.0,
#  255944388.0,
#  255920584.0,
#  255811040.0,
#  255933251.0,
#  255931419.0,
#  255934945.0,
#  255916088.0,
#  255814181.0,
#  255947816.0,
#  255944805.0,
#  255854203.0,
#  255944593.0,
#  255922756.0,
#  255918123.0,
#  255890196.0,
#  255948357.0,
#  255863756.0,
#  255914157.0,
#  255843060.0,
#  255879602.0,
#  255881057.0,
#  255798869.0,
#  255867882.0,
#  255924287.0,
#  255921578.0,
#  255915013.0,
#  255948380.0,
#  255918762.0,
#  255877324.0,
#  255888642.0,
#  255913201.0,
#  255925976.0,
#  255914961.0,
#  255939052.0,
#  255872447.0,
#  255862728.0,
#  255842082.0,
#  255820860.0,
#  255909190.0,
#  255866802.0,
#  255947523.0,
#  255907403.0,
#  255898733.0,
#  255844933.0,
#  255944422.0,
#  255934616.0,
#  255817234.0,
#  255878183.0,
#  255887349.0,
#  255823493.0,
#  255944097.0,
#  255938259.0]

# %%
len(greedy)
# Out:
# 528
