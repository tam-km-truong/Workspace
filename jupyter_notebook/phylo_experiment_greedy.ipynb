# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# %%
data = pd.read_csv("./data/experiment.csv",header=0, sep = "\t", index_col = '#Path')

# %%
data
# Out:
#                                                     Size (est.)
# #Path
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   14975419.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   14600549.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   14874176.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   14024856.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   14672608.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   14445750.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   14703403.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   12845824.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMEA9...   13042010.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMEA8...   13440508.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   10688887.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   10683020.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   10643664.0
# /Users/ktruong/data/661k/tuberculosis_30/SAMN02...   10403310.0
# ...
