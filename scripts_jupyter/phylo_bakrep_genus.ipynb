# %%
import pandas as pd
import numpy as np
import os

# %%
bakrep_metadata = pd.read_csv("data/bakrep-export_18112024.tsv",sep='\t', low_memory=False, index_col="#id")

# %%
bakrep_metadata.columns
# Out:
# Index(['bakta.genome.genus', 'bakta.genome.species', 'bakta.genome.strain',
#        'bakta.stats.no_sequences', 'bakta.stats.size', 'bakta.stats.gc',
#        'bakta.stats.n_ratio', 'bakta.stats.n50', 'bakta.stats.coding_ratio',
#        'gtdbtk.classification.domain', 'gtdbtk.classification.phylum',
#        'gtdbtk.classification.class', 'gtdbtk.classification.order',
#        'gtdbtk.classification.family', 'gtdbtk.classification.genus',
#        'gtdbtk.classification.species', 'mlst.sequence_type',
#        'checkm2.quality.completeness', 'checkm2.quality.contamination',
#        'metadata.accession', 'metadata.collected_by',
#        'metadata.collection_date', 'metadata.country', 'metadata.host',
#        'metadata.host_sex', 'metadata.host_status', 'metadata.host_tax_id',
#        'metadata.instrument_model', 'metadata.instrument_platform',
#        'metadata.isolate', 'metadata.isolation_source', 'metadata.location',
# ...

# %%
bakrep_metadata.head()
# Out:
#              bakta.genome.genus bakta.genome.species bakta.genome.strain  \
# #id
# SAMD00000344      Lactobacillus       hokkaidonensis             LOOC260
# SAMD00000345      Lactobacillus               oryzae               SG293
# SAMD00000355      Streptococcus             pyogenes                M3-b
# SAMD00000550    Corynebacterium           glutamicum               CS176
# SAMD00000552    Corynebacterium          suranareeae                 N24
#
#               bakta.stats.no_sequences  bakta.stats.size  bakta.stats.gc  \
# #id
# SAMD00000344                      74.0         2359987.0        0.381423
# SAMD00000345                     124.0         1876547.0        0.427850
# SAMD00000355                      61.0         1868526.0        0.384668
# SAMD00000550                      68.0         3082883.0        0.542123
# SAMD00000552                      38.0         3499857.0        0.518016
#
# ...

# %%
species_groups =  bakrep_metadata.groupby(['gtdbtk.classification.genus']).groups
group_sizes = bakrep_metadata.groupby(['gtdbtk.classification.genus']).size()

# %%
group_sizes.sort_values(ascending=False)
# Out:
# gtdbtk.classification.genus
# Salmonella        181582
# Escherichia        89631
# Streptococcus      83576
# Mycobacterium      55690
# Staphylococcus     51333
#                    ...
# Monaibacterium         1
# Moheibacter            1
# Moellerella            1
# Modestobacter          1
# 01-FULL-49-22b         1
# Length: 2466, dtype: int64

# %%
bakrep_metadata[bakrep_metadata['gtdbtk.classification.genus'] == 'Mycobacterium'].groupby(['gtdbtk.classification.species']).size().sort_values(ascending=False)
# Out:
# gtdbtk.classification.species
# Mycobacterium tuberculosis      49020
# Mycobacterium abscessus          2689
# Mycobacterium marinum             891
# Mycobacterium intracellulare      880
# Mycobacterium avium               835
#                                 ...
# Mycobacterium sp001665575           1
# Mycobacterium sp001665395           1
# Mycobacterium sp001665295           1
# Mycobacterium sp001665255           1
# Mycobacterium branderi              1
# Length: 173, dtype: int64
